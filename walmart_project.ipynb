# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv(r'C:\Users\DELL\Desktop\Dataset\Walmart (1).csv')
data1
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
data1.set_index('Date', inplace=True)
data1
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 05-02-2010      1    1643690.90             0        42.31       2.572
# 12-02-2010      1    1641957.44             1        38.51       2.548
# 19-02-2010      1    1611968.17             0        39.93       2.514
# 26-02-2010      1    1409727.59             0        46.63       2.561
# 05-03-2010      1    1554806.68             0        46.50       2.625
# ...           ...           ...           ...          ...         ...
# 28-09-2012     45     713173.95             0        64.88       3.997
# 05-10-2012     45     733455.07             0        64.89       3.985
# 12-10-2012     45     734464.36             0        54.47       4.000
# 19-10-2012     45     718125.53             0        56.47       3.969
# 26-10-2012     45     760281.43             0        58.85       3.882
#
#                    CPI  Unemployment
# Date
# 05-02-2010  211.096358         8.106
# 12-02-2010  211.242170         8.106
# 19-02-2010  211.289143         8.106
# 26-02-2010  211.319643         8.106
# 05-03-2010  211.350143         8.106
# ...                ...           ...
# 28-09-2012  192.013558         8.684
# 05-10-2012  192.170412         8.667
# 12-10-2012  192.327265         8.667
# 19-10-2012  192.330854         8.667
# 26-10-2012  192.308899         8.667
#
# [6435 rows x 7 columns]

# %%
# There are about 45 different stores in this dataset. Lets select the any store id from 1-45
a= int(input("Enter the store id:"))
store = data1[data1.Store == a]
# Out:
# Enter the store id:17

# %%
store
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 05-02-2010     17     789036.02             0        23.11       2.666
# 12-02-2010     17     841951.91             1        18.36       2.671
# 19-02-2010     17     800714.00             0        25.06       2.654
# 26-02-2010     17     749549.55             0        15.64       2.667
# 05-03-2010     17     783300.05             0        31.58       2.681
# ...           ...           ...           ...          ...         ...
# 28-09-2012     17     972716.24             0        57.77       3.821
# 05-10-2012     17     952609.17             0        52.81       3.815
# 12-10-2012     17     919878.34             0        44.82       3.797
# 19-10-2012     17     957356.84             0        48.16       3.781
# 26-10-2012     17     943465.29             0        39.94       3.755
#
#                    CPI  Unemployment
# Date
# 05-02-2010  126.442065         6.548
# 12-02-2010  126.496258         6.548
# 19-02-2010  126.526286         6.548
# 26-02-2010  126.552286         6.548
# 05-03-2010  126.578286         6.548
# ...                ...           ...
# 28-09-2012  131.043000         5.936
# 05-10-2012  131.075667         5.527
# 12-10-2012  131.108333         5.527
# 19-10-2012  131.149968         5.527
# 26-10-2012  131.193097         5.527
#
# [143 rows x 7 columns]

# %%
sales = pd.DataFrame(store.Weekly_Sales.groupby(store.index).sum())
sales.dtypes
# Out:
# Weekly_Sales    float64
# dtype: object

# %%
sales
# Out:
#             Weekly_Sales
# Date
# 01-04-2011     795859.23
# 01-06-2012     938914.28
# 01-07-2011     940554.34
# 01-10-2010     829207.27
# 02-03-2012     856178.47
# ...                  ...
# 30-07-2010     833517.19
# 30-09-2011     868191.05
# 30-12-2011     777207.30
# 31-08-2012     865924.20
# 31-12-2010     635862.55
#
# [143 rows x 1 columns]

# %%
#remove date from index to change its dtype because it clearly isnt acceptable.
sales.reset_index(inplace = True)

# %%
sales
# Out:
#            Date  Weekly_Sales
# 0    01-04-2011     795859.23
# 1    01-06-2012     938914.28
# 2    01-07-2011     940554.34
# 3    01-10-2010     829207.27
# 4    02-03-2012     856178.47
# ..          ...           ...
# 138  30-07-2010     833517.19
# 139  30-09-2011     868191.05
# 140  30-12-2011     777207.30
# 141  31-08-2012     865924.20
# 142  31-12-2010     635862.55
#
# [143 rows x 2 columns]

# %%
#converting 'date' column to a datetime type
sales['Date'] = pd.to_datetime(sales['Date'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '13-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '13-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '13-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '13-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '13-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '14-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '14-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '14-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '14-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '15-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '15-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '15-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '15-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '16-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '16-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '16-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '16-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '16-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '17-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '17-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '17-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '17-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '17-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '18-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '18-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '18-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '18-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '18-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '19-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '19-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '19-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '19-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '19-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '20-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '20-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '20-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '20-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '20-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '21-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '21-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '21-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '21-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '22-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '22-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '22-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '22-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '23-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '23-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '23-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '23-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '23-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '24-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '24-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '24-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '24-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '24-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '25-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '25-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '25-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '25-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '25-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '26-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '26-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '26-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '26-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '26-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '27-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '27-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '27-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '27-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '27-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '28-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '28-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '28-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '28-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '29-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '29-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '29-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '29-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '30-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '30-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '30-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '30-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '30-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '31-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\69068200.py:2: UserWarning: Parsing '31-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])

# %%
sales
# Out:
#           Date  Weekly_Sales
# 0   2011-01-04     795859.23
# 1   2012-01-06     938914.28
# 2   2011-01-07     940554.34
# 3   2010-01-10     829207.27
# 4   2012-02-03     856178.47
# ..         ...           ...
# 138 2010-07-30     833517.19
# 139 2011-09-30     868191.05
# 140 2011-12-30     777207.30
# 141 2012-08-31     865924.20
# 142 2010-12-31     635862.55
#
# [143 rows x 2 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(sales.Weekly_Sales, period=12)  
fig = plt.figure()  
fig = decomposition.plot()  
fig.set_size_inches(15, 10)
plt.show()

# %%
# resetting date back to the index
sales.set_index('Date',inplace = True)

# %%
sales.Weekly_Sales.plot(figsize=(10,6), title= 'Weekly Sales of a Store', fontsize=14, color = 'blue')
plt.show()

# %%
#lets compare the 2012 data of two stores
# Lets take store 5 data for analysis
store5 = data1[data1.Store == 5]
# there are about 45 different stores in this dataset.

sales5 = pd.DataFrame(store5.Weekly_Sales.groupby(store5.index).sum())
sales5.dtypes
# Grouped weekly sales by store 6

#remove date from index to change its dtype because it clearly isnt acceptable.
sales5.reset_index(inplace = True)

#converting 'date' column to a datetime type
sales5['Date'] = pd.to_datetime(sales5['Date'])
# resetting date back to the index
sales5.set_index('Date',inplace = True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '13-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '13-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '13-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '13-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '13-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '14-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '14-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '14-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '14-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '15-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '15-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '15-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '15-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '16-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '16-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '16-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '16-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '16-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '17-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '17-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '17-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '17-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '17-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '18-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '18-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '18-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '18-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '18-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '19-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '19-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '19-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '19-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '19-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '20-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '20-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '20-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '20-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '20-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '21-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '21-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '21-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '21-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '22-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '22-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '22-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '22-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '23-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '23-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '23-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '23-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '23-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '24-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '24-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '24-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '24-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '24-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '25-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '25-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '25-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '25-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '25-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '26-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '26-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '26-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '26-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '26-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '27-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '27-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '27-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '27-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '27-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '28-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '28-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '28-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '28-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '29-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '29-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '29-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '29-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '30-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '30-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '30-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '30-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '30-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '31-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\337423408.py:14: UserWarning: Parsing '31-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])

# %%
y1=sales.Weekly_Sales
y2=sales5.Weekly_Sales

# %%
y1['2012'].plot(figsize=(15, 6),legend=True, color = 'chocolate')
y2['2012'].plot(figsize=(15, 6), legend=True, color = 'turquoise')
plt.ylabel('Weekly Sales')
plt.title('Store17 vs Store5 on 2012', fontsize = '16')
plt.show()

# %%
# Clearly we can see the irregularities

# %%
#Sarima=sar(seasonal autoregression)p,si=(seasonal differencing)d,sma-(seasonal moving average)q

# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 5)
import itertools
# Generate all different combinations of p, d and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, d and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]

# %%
seasonal_pdq
# Out:
# [(0, 0, 0, 52),
#  (0, 0, 1, 52),
#  (0, 0, 2, 52),
#  (0, 0, 3, 52),
#  (0, 0, 4, 52),
#  (0, 1, 0, 52),
#  (0, 1, 1, 52),
#  (0, 1, 2, 52),
#  (0, 1, 3, 52),
#  (0, 1, 4, 52),
#  (0, 2, 0, 52),
#  (0, 2, 1, 52),
force_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4078      0.104     -3.934      0.000      -0.611      -0.205
# ar.S.L52      -0.5565      0.078     -7.151      0.000      -0.709      -0.404
# sigma2      3.166e+10   1.09e-13   2.91e+23      0.000    3.17e+10    3.17e+10
# ==============================================================================

# %%
plt.style.use('seaborn-pastel')
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2012-07-27'), dynamic=False)
pred_ci = pred.conf_int()

# %%
ax = y1['2010':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7)

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='y', alpha=.1)

ax.set_xlabel('Time Period')
ax.set_ylabel('Sales')
plt.legend()

plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\228998974.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   ax = y1['2010':].plot(label='observed')

# %%
y_forecasted = pred.predicted_mean
y_truth = y1['2012-7-27':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 29475064959.42

# %%
pred_dynamic = results.get_prediction(start=pd.to_datetime('2012-7-27'), dynamic=True, full_results=True)
pred_dynamic_ci = pred_dynamic.conf_int()

# %%
ax = y1['2010':].plot(label='observed', figsize=(12, 8))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_ci.index,
                pred_dynamic_ci.iloc[:, 0],
                pred_dynamic_ci.iloc[:, 1], color='y', alpha=.1)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2012-7-26'), y1.index[-1],
                 alpha=.1, zorder=-1)

ax.set_xlabel('Time Period')
ax.set_ylabel('Sales')

plt.legend()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_12484\1451197349.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   ax = y1['2010':].plot(label='observed', figsize=(12, 8))

# %%
import numpy as np
# Extract the predicted and true values of our time series
y_forecasted = pred_dynamic.predicted_mean
print(y_forecasted)
# Out:
# Date
# 2012-07-27    1.011711e+06
# 2010-08-27    8.484828e+05
# 2011-01-28    1.056065e+06
# 2010-05-28    9.121256e+05
# 2012-09-28    8.672673e+05
# 2011-10-28    1.037163e+06
# 2011-04-29    8.139501e+05
# 2012-06-29    9.373659e+05
# 2011-07-29    8.887297e+05
# 2010-10-29    1.077579e+06
# 2012-03-30    8.895842e+05
# 2010-04-30    7.963543e+05
# 2010-07-30    8.727806e+05
# 2011-09-30    8.523733e+05
# 2011-12-30    8.746678e+05
# 2012-08-31    8.150837e+05
# 2010-12-31    7.769862e+05
# Name: predicted_mean, dtype: float64

# %%
y_truth = y1['2012-7-27':]

print(y_truth)
# Out:
# Date
# 2012-08-06     987990.24
# 2012-09-03     860224.98
# 2012-10-02     880165.70
# 2012-10-08     849074.04
# 2012-11-05     944100.30
# 2012-12-10     919878.34
# 2012-09-14    1071040.22
# 2012-08-17     844928.17
# 2012-10-19     957356.84
# 2012-09-21     938303.28
# 2012-08-24     924299.78
# 2012-10-26     943465.29
# 2012-07-27     907493.24
# 2012-09-28     972716.24
# 2012-08-31     865924.20
# Name: Weekly_Sales, dtype: float64

# %%
# Compute the Root mean square error
rmse = np.sqrt(((y_forecasted - y_truth) ** 2).mean())
print('The Root Mean Squared Error of our forecasts is {}'.format(round(rmse, 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 90490.37

# %%
Residual= y_forecasted - y_truth
print("Residual for Store1",np.abs(Residual).sum())
# Out:
# Residual for Store1 721358.0139316102

# %%
# Get forecast 12 weeks ahead in future
pred_uc = results.get_forecast(steps=12)

print(pred_uc)
# Out:
# <statsmodels.tsa.statespace.mlemodel.PredictionResultsWrapper object at 0x0000023417EC2910>
# C:\Users\DELL\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

# %%
ax = y1.plot(label='observed', figsize=(12, 8))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Time Period')
ax.set_ylabel('Sales')

plt.legend()
plt.show()

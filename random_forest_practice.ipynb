# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/Users/sibu/Desktop/Train (3).csv')
df
# Out:
#       INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  \
# 0       CR_102659  04-JUL-04    0   36   34    2    1    5    6    1    6
# 1       CR_189752  18-JUL-17    1   37   37    0    0   11   17    1    6
# 2       CR_184637  15-MAR-17    0    3    2    3    5    1    0    2    3
# 3       CR_139071  13-FEB-09    0   33   32    2    1    7    1    1    6
# 4       CR_109335  13-APR-05    0   33   32    2    1    8    3    0    5
# ...           ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 23851    CR_88991  11-JAN-02    1   47   48    7    3   15   10    1    5
# 23852    CR_46369  05-FEB-97    0   33   32    2    1    5    6    0    5
# 23853   CR_157556  03-APR-12    0   25   25    9    0    3    5    1    6
# 23854   CR_103180  25-JAN-04    0   39   39    6    5    2    7    1    6
# 23855    CR_22575  08-NOV-94    7   36   34    2    1    9    8    0    5
#
#        X_10  X_11  X_12  X_13  X_14  X_15  MALICIOUS_OFFENSE
# ...

# %%
df.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_102659  04-JUL-04    0   36   34    2    1    5    6    1    6     1
# 1   CR_189752  18-JUL-17    1   37   37    0    0   11   17    1    6     1
# 2   CR_184637  15-MAR-17    0    3    2    3    5    1    0    2    3     1
# 3   CR_139071  13-FEB-09    0   33   32    2    1    7    1    1    6     1
# 4   CR_109335  13-APR-05    0   33   32    2    1    8    3    0    5     1
#
#    X_11  X_12  X_13  X_14  X_15  MALICIOUS_OFFENSE
# 0   174   1.0    92    29    36                  0
# 1   236   1.0   103   142    34                  1
# 2   174   1.0   110    93    34                  1
# 3   249   1.0    72    29    34                  1
# 4   174   0.0   112    29    43                  1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   INCIDENT_ID        23856 non-null  object
#  1   DATE               23856 non-null  object
#  2   X_1                23856 non-null  int64
#  3   X_2                23856 non-null  int64
#  4   X_3                23856 non-null  int64
#  5   X_4                23856 non-null  int64
#  6   X_5                23856 non-null  int64
#  7   X_6                23856 non-null  int64
#  8   X_7                23856 non-null  int64
#  9   X_8                23856 non-null  int64
#  10  X_9                23856 non-null  int64
#  11  X_10               23856 non-null  int64
#  12  X_11               23856 non-null  int64
#  13  X_12               23674 non-null  float64
#  14  X_13               23856 non-null  int64
#  15  X_14               23856 non-null  int64
# ...

# %%
df.shape
# Out:
# (23856, 18)

# %%
df['INCIDENT_ID'].nunique()
# Out:
# 23856

# %%
df=df.drop(['INCIDENT_ID','DATE'],axis=1)

# %%
df.isnull().sum()
# Out:
# X_1                    0
# X_2                    0
# X_3                    0
# X_4                    0
# X_5                    0
# X_6                    0
# X_7                    0
# X_8                    0
# X_9                    0
# X_10                   0
# X_11                   0
# X_12                 182
# X_13                   0
# X_14                   0
# X_15                   0
# MALICIOUS_OFFENSE      0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# X_1                  0
# X_2                  0
# X_3                  0
# X_4                  0
# X_5                  0
# X_6                  0
# X_7                  0
# X_8                  0
# X_9                  0
# X_10                 0
# X_11                 0
# X_12                 0
# X_13                 0
# X_14                 0
# X_15                 0
# MALICIOUS_OFFENSE    0
# dtype: int64

# %%
df.describe().T
# Out:
#                      count        mean        std  min    25%    50%    75%  \
# X_1                23674.0    0.481287   1.435650  0.0    0.0    0.0    0.0
# X_2                23674.0   24.792895  15.249384  0.0    7.0   24.0   36.0
# X_3                23674.0   24.644547  15.148753  0.0    8.0   24.0   35.0
# X_4                23674.0    4.279463   2.947699  0.0    2.0    4.0    6.0
# X_5                23674.0    2.457886   1.964675  0.0    1.0    3.0    5.0
# X_6                23674.0    6.159965   4.470403  1.0    3.0    5.0    8.0
# X_7                23674.0    4.881304   3.881914  0.0    2.0    4.0    7.0
# X_8                23674.0    0.974867   1.457230  0.0    0.0    1.0    1.0
# X_9                23674.0    4.924263   1.366316  0.0    5.0    5.0    6.0
# X_10               23674.0    1.246557   1.123247  1.0    1.0    1.0    1.0
# X_11               23674.0  207.190293  93.325984  0.0  174.0  249.0  249.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.feature_selection import RFECV
from sklearn.model_selection import train_test_split,StratifiedKFold
from sklearn.ensemble import RandomForestClassifier

# %%
X=df.drop(['MALICIOUS_OFFENSE'],axis=1)
y=df['MALICIOUS_OFFENSE']

# %%
rfe=RFECV(RandomForestClassifier(),cv=StratifiedKFold(4))

# %%
rfe.fit(X,y)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=4, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier())

# %%
print(rfe.n_features_)
# Out:
# 4

# %% [raw]
# rfe.ranking_

# %%
rfe.get_support()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#         True,  True,  True, False, False,  True])

# %%
feature_selected=X.columns[rfe.get_support()]
feature_selected
# Out:
# Index(['X_10', 'X_11', 'X_12', 'X_15'], dtype='object')

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train=rfe.transform(X_train)
X_test=rfe.transform(X_test)

# %%
model=RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
confusion_matrix(y_test,pred)
# Out:
# array([[ 300,    2],
#        [   6, 6795]])

# %%
accuracy_score(y_test,pred)
# Out:
# 0.99887371533155
